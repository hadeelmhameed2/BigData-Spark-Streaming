# %%
pip install kafka-python
# Out:
# Collecting kafka-python
#   Downloading kafka_python-2.3.0-py2.py3-none-any.whl (326 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 326.3/326.3 KB 5.8 MB/s eta 0:00:00a 0:00:01
# Installing collected packages: kafka-python
# Successfully installed kafka-python-2.3.0
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pyspark
# Out:
# Requirement already satisfied: pyspark in /root/.venv3.11/lib/python3.11/site-packages (4.1.0)
# Requirement already satisfied: py4j<0.10.9.10,>=0.10.9.7 in /root/.venv3.11/lib/python3.11/site-packages (from pyspark) (0.10.9.9)
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
import pyspark

# %%
os.environ['PYSPARK_SUBMIT_ARGS'] = f'--packages org.apache.spark:spark-sql-kafka-0-10_2.13:{pyspark.__version__} pyspark-shell'
os.environ['SPARK_SUBMIT_OPTS'] = '-Djdk.security.auth.login.Config=ignore'

# %%
KAFKA_BROKER_URL = "localhost:9092"
KAFKA_TOPIC = "wikimedia_topic_1"

# %%
pip install requests
# Out:
# Requirement already satisfied: requests in /root/.venv3.11/lib/python3.11/site-packages (2.32.5)
# Requirement already satisfied: certifi>=2017.4.17 in /root/.venv3.11/lib/python3.11/site-packages (from requests) (2025.11.12)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /root/.venv3.11/lib/python3.11/site-packages (from requests) (2.6.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /root/.venv3.11/lib/python3.11/site-packages (from requests) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /root/.venv3.11/lib/python3.11/site-packages (from requests) (3.11)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install sseclient
# Out:
# Collecting sseclient
#   Downloading sseclient-0.0.27.tar.gz (7.5 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: requests>=2.9 in /root/.venv3.11/lib/python3.11/site-packages (from sseclient) (2.32.5)
# Requirement already satisfied: six in /root/.venv3.11/lib/python3.11/site-packages (from sseclient) (1.17.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /root/.venv3.11/lib/python3.11/site-packages (from requests>=2.9->sseclient) (2.6.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /root/.venv3.11/lib/python3.11/site-packages (from requests>=2.9->sseclient) (3.4.4)
# Requirement already satisfied: certifi>=2017.4.17 in /root/.venv3.11/lib/python3.11/site-packages (from requests>=2.9->sseclient) (2025.11.12)
# Requirement already satisfied: idna<4,>=2.5 in /root/.venv3.11/lib/python3.11/site-packages (from requests>=2.9->sseclient) (3.11)
# Using legacy 'setup.py install' for sseclient, since package 'wheel' is not installed.
# Installing collected packages: sseclient
#   Running setup.py install for sseclient ... done
# Successfully installed sseclient-0.0.27
# Note: you may need to restart the kernel to use updated packages.

# %%
import threading
import time
from kafka import KafkaConsumer
from kafka import KafkaProducer
from pyspark.sql import SparkSession
from pyspark.sql.functions import col, from_json, expr
from pyspark.sql.types import StructType, StringType, IntegerType
from pyspark.streaming import StreamingContext

# %%
# *** Note!!! **** At this point you need to have Kafka broker running. See Setup for Docker and Kafka.

producer = KafkaProducer(bootstrap_servers=KAFKA_BROKER_URL)

# %%
# *** Note!!! **** In order to read wikimedia changes, you need to obtain Access Token 
# See instructions in Readm about how to authenticate to Wikimedia page

# %%
import requests
from sseclient import SSEClient
URL = 'https://stream.wikimedia.org/v2/stream/recentchange'
headers = {
    "User-Agent": "Meow",
    "Authorization": "Bearer NO_NO"
}
def relay():
    events = SSEClient(URL, headers=headers, timeout=30)
    for i in range(100):
        for event in events:
            if event.event == 'message' and event.data != None:
                message = event.data.encode("utf-8")
                producer.send(KAFKA_TOPIC, value=message)
                break
threading.Thread(target=relay).start()

# %%
# *** Note!!! **** Before continue to the next phase, make sure that you have a topic and events in it.
# See 'Lookup Kafka Topics' in the Readme.

# %%
spark = SparkSession.builder \
    .appName("PySpark-jupyter-streaming") \
    .config("spark.jars.packages", "org.apache.spark:spark-sql-kafka-0-10_2.13:{pyspark.__version__}") \
    .config("spark.sql.streaming.checkpointLocation", "./checkpoint") \
    .getOrCreate()
# Out:
# WARNING: Using incubator modules: jdk.incubator.vector
# :: loading settings :: url = jar:file:/root/.venv3.11/lib/python3.11/site-packages/pyspark/jars/ivy-2.5.3.jar!/org/apache/ivy/core/settings/ivysettings.xml
# Ivy Default Cache set to: /root/.ivy2.5.2/cache
# The jars for the packages stored in: /root/.ivy2.5.2/jars
# org.apache.spark#spark-sql-kafka-0-10_2.13 added as a dependency
# :: resolving dependencies :: org.apache.spark#spark-submit-parent-049b4fa1-b793-4356-ac60-24f91b5f2310;1.0
# 	confs: [default]
# 	found org.apache.spark#spark-sql-kafka-0-10_2.13;4.1.0 in central
# 	found org.apache.spark#spark-token-provider-kafka-0-10_2.13;4.1.0 in central
# 	found org.apache.kafka#kafka-clients;3.9.1 in central
# 	found org.lz4#lz4-java;1.8.0 in central
# 	found org.xerial.snappy#snappy-java;1.1.10.8 in central
# 	found org.slf4j#slf4j-api;2.0.17 in central
# 	found org.apache.hadoop#hadoop-client-runtime;3.4.2 in central
# 	found org.apache.hadoop#hadoop-client-api;3.4.2 in central
# 	found com.google.code.findbugs#jsr305;3.0.0 in central
# 	found org.scala-lang.modules#scala-parallel-collections_2.13;1.2.0 in central
# 	found org.apache.commons#commons-pool2;2.12.1 in central
# downloading https://repo1.maven.org/maven2/org/apache/spark/spark-sql-kafka-0-10_2.13/4.1.0/spark-sql-kafka-0-10_2.13-4.1.0.jar ...
# 	[SUCCESSFUL ] org.apache.spark#spark-sql-kafka-0-10_2.13;4.1.0!spark-sql-kafka-0-10_2.13.jar (391ms)
# downloading https://repo1.maven.org/maven2/org/apache/spark/spark-token-provider-kafka-0-10_2.13/4.1.0/spark-token-provider-kafka-0-10_2.13-4.1.0.jar ...
# 	[SUCCESSFUL ] org.apache.spark#spark-token-provider-kafka-0-10_2.13;4.1.0!spark-token-provider-kafka-0-10_2.13.jar (45ms)
# downloading https://repo1.maven.org/maven2/org/scala-lang/modules/scala-parallel-collections_2.13/1.2.0/scala-parallel-collections_2.13-1.2.0.jar ...
# 	[SUCCESSFUL ] org.scala-lang.modules#scala-parallel-collections_2.13;1.2.0!scala-parallel-collections_2.13.jar (182ms)
# downloading https://repo1.maven.org/maven2/org/apache/kafka/kafka-clients/3.9.1/kafka-clients-3.9.1.jar ...
# 	[SUCCESSFUL ] org.apache.kafka#kafka-clients;3.9.1!kafka-clients.jar (636ms)
# downloading https://repo1.maven.org/maven2/com/google/code/findbugs/jsr305/3.0.0/jsr305-3.0.0.jar ...
# 	[SUCCESSFUL ] com.google.code.findbugs#jsr305;3.0.0!jsr305.jar (40ms)
# downloading https://repo1.maven.org/maven2/org/apache/commons/commons-pool2/2.12.1/commons-pool2-2.12.1.jar ...
# 	[SUCCESSFUL ] org.apache.commons#commons-pool2;2.12.1!commons-pool2.jar (48ms)
# downloading https://repo1.maven.org/maven2/org/apache/hadoop/hadoop-client-runtime/3.4.2/hadoop-client-runtime-3.4.2.jar ...
# 	[SUCCESSFUL ] org.apache.hadoop#hadoop-client-runtime;3.4.2!hadoop-client-runtime.jar (616ms)
# downloading https://repo1.maven.org/maven2/org/lz4/lz4-java/1.8.0/lz4-java-1.8.0.jar ...
# 	[SUCCESSFUL ] org.lz4#lz4-java;1.8.0!lz4-java.jar (48ms)
# downloading https://repo1.maven.org/maven2/org/xerial/snappy/snappy-java/1.1.10.8/snappy-java-1.1.10.8.jar ...
# 	[SUCCESSFUL ] org.xerial.snappy#snappy-java;1.1.10.8!snappy-java.jar(bundle) (59ms)
# downloading https://repo1.maven.org/maven2/org/slf4j/slf4j-api/2.0.17/slf4j-api-2.0.17.jar ...
# 	[SUCCESSFUL ] org.slf4j#slf4j-api;2.0.17!slf4j-api.jar (39ms)
# downloading https://repo1.maven.org/maven2/org/apache/hadoop/hadoop-client-api/3.4.2/hadoop-client-api-3.4.2.jar ...
# 	[SUCCESSFUL ] org.apache.hadoop#hadoop-client-api;3.4.2!hadoop-client-api.jar (243ms)
# :: resolution report :: resolve 8654ms :: artifacts dl 2397ms
# 	:: modules in use:
# 	com.google.code.findbugs#jsr305;3.0.0 from central in [default]
# 	org.apache.commons#commons-pool2;2.12.1 from central in [default]
# 	org.apache.hadoop#hadoop-client-api;3.4.2 from central in [default]
# 	org.apache.hadoop#hadoop-client-runtime;3.4.2 from central in [default]
# 	org.apache.kafka#kafka-clients;3.9.1 from central in [default]
# 	org.apache.spark#spark-sql-kafka-0-10_2.13;4.1.0 from central in [default]
# 	org.apache.spark#spark-token-provider-kafka-0-10_2.13;4.1.0 from central in [default]
# 	org.lz4#lz4-java;1.8.0 from central in [default]
# 	org.scala-lang.modules#scala-parallel-collections_2.13;1.2.0 from central in [default]
# 	org.slf4j#slf4j-api;2.0.17 from central in [default]
# 	org.xerial.snappy#snappy-java;1.1.10.8 from central in [default]
# 	---------------------------------------------------------------------
# 	|                  |            modules            ||   artifacts   |
# 	|       conf       | number| search|dwnlded|evicted|| number|dwnlded|
# 	---------------------------------------------------------------------
# 	|      default     |   11  |   11  |   11  |   0   ||   11  |   11  |
# 	---------------------------------------------------------------------
# :: retrieving :: org.apache.spark#spark-submit-parent-049b4fa1-b793-4356-ac60-24f91b5f2310
# 	confs: [default]
# 	11 artifacts copied, 0 already retrieved (62936kB/336ms)
# 26/01/16 23:06:26 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).

# %%
kafka_df = spark.readStream \
  .format("kafka") \
  .option("kafka.bootstrap.servers", KAFKA_BROKER_URL) \
  .option("subscribe", KAFKA_TOPIC) \
  .option("startingOffsets", "earliest") \
  .load()

# %%
schema = StructType() \
    .add("id", IntegerType()) \
    .add("type", StringType()) \
    .add("comment", StringType()) \
    .add("user", StringType()) \
    .add("title", StringType()) \
    .add("server_name", StringType())

# Transform data to dataframe of json format
parsed_df = kafka_df.selectExpr("CAST(value AS STRING)") \
    .select(from_json(col("value"), schema).alias("data")) \
    .select("data.*")

# %%
parsed_df.writeStream \
    .outputMode("append") \
    .format("console") \
    .start()
# Out:
# 26/01/16 23:06:45 WARN ResolveWriteToStream: spark.sql.adaptive.enabled is not supported in streaming DataFrames/Datasets and will be disabled.

# %%
parsed_df.createOrReplaceTempView("parsed_df")

spark.sql("select user, count(*) as count from parsed_df group by user") \
.writeStream \
.outputMode("complete") \
.format("console") \
.start()
# Out:
# 26/01/16 23:06:48 WARN ResolveWriteToStream: spark.sql.adaptive.enabled is not supported in streaming DataFrames/Datasets and will be disabled.

# %%
spark.sql("select type, count(*) as count from parsed_df group by type") \
.writeStream \
.outputMode("complete") \
.format("console") \
.start()
# Out:
# 26/01/16 23:06:48 WARN MicroBatchExecution: Disabling AQE since AQE is not supported in stateful workloads.
# 26/01/16 23:06:48 WARN ResolveWriteToStream: spark.sql.adaptive.enabled is not supported in streaming DataFrames/Datasets and will be disabled.
# 26/01/16 23:06:48 WARN MicroBatchExecution: Disabling AQE since AQE is not supported in stateful workloads.
# -------------------------------------------
# Batch: 0
# -------------------------------------------
# [Stage 1:>                  (0 + 1) / 1][Stage 3:>                  (0 + 0) / 1]
# +----------+----------+--------------------+------------------+--------------------+--------------------+
# |        id|      type|             comment|              user|               title|         server_name|
# +----------+----------+--------------------+------------------+--------------------+--------------------+
# |      NULL|      NULL|                NULL|              NULL|                NULL|                NULL|
# |      NULL|categorize|[[:Category:Prese...|     IvanScrooge98|Category:Non-empt...|commons.wikimedia...|
# |1986731190|       log|[[Wikipedia:Categ...|    JJMC89 bot III|Category talk:Isr...|    en.wikipedia.org|
# |      NULL|categorize|[[:Category:Prese...|     IvanScrooge98|Category:1974 San...|commons.wikimedia...|
# |      NULL|categorize|[[:Category:Prese...|     IvanScrooge98|Category:Category...|commons.wikimedia...|
# |      NULL|categorize|[[:File:Schloß Po...|        Rkieferbot|Category:Taken wi...|commons.wikimedia...|
# |1986731191|      edit|         /* Clubs */|    GiofanniRahman|2026 J1 100 Year ...|    en.wikipedia.org|
# | 101973458|      edit|/* کتاب‌هایی دربا...|           Tisfoon|     عبدالله (تن‌تن)|    fa.wikipedia.org|
# | 565659232|      edit|/* Accidents de p...|           Xtof054|       Font Estramar|    fr.wikipedia.org|
# |  57479265|      edit|                    |           Ambra75|Марела Карачоло (...|    bg.wikipedia.org|
# |      NULL|      edit|report update for...|            KrBot2|Wikidata:Database...|    www.wikidata.org|
# |      NULL|      edit|/* wbsetclaim-cre...|PantheraLeo1359531|File:Dop10rgb 32 ...|commons.wikimedia...|
# |1986731192|categorize|[[:Category:Gover...|    JJMC89 bot III|Category:Categori...|    en.wikipedia.org|
# |      NULL|      edit|removed [[Categor...|    Ivonna Nowicka|Category:Stanisła...|commons.wikimedia...|
# |1986731193|categorize|[[:Category:Gover...|    JJMC89 bot III|Category:Categori...|    en.wikipedia.org|
# |1986731194|categorize|[[:Category:Gover...|    JJMC89 bot III|Category:All cate...|    en.wikipedia.org|
# |      NULL|      edit|/* wbsetdescripti...|          Escarbot|          Q125894553|    www.wikidata.org|
# |      NULL|      edit|/* wbsetclaim-cre...|             Rebot|           Q10694347|    www.wikidata.org|
# | 565659233|      edit|                  li|          Bédévore|Guerre de Bosnie-...|    fr.wikipedia.org|
# |      NULL|categorize|[[:File:Dop10rgb ...|PantheraLeo1359531|Category:Data lic...|commons.wikimedia...|
# +----------+----------+--------------------+------------------+--------------------+--------------------+
# only showing top 20 rows
# -------------------------------------------
# Batch: 0
# -------------------------------------------
# +----------+-----+
# |      type|count|
# +----------+-----+
# |       new|    2|
# |       log|   11|
# |      NULL|    1|
# |      edit|   35|
# |categorize|   51|
# +----------+-----+
# [Stage 4:================>                                       (58 + 1) / 200]
